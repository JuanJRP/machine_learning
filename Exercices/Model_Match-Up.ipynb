# %% [markdown]
# ## 🚀 Warm-Up Exercise: "Model Match-Up Challenge" 🧠⚙️
#
#
# **🎯 Objective:** You will practice:
#
# - Applying classification models (KNN, Naive Bayes, Logistic Regression, SVM)
# - Applying regression models (Linear Regression)
# - Visualizing results
#
#
# ###**📝 Instructions:**
#
# ####1️⃣ Classification Task
#
# Load ```classification_dataset.csv``` using pandas.
#
# - Split the data: Features: Feature1, Feature2; Target: Target
# - Choose one classification model.
# - Train the model and Make predictions.\
# - Plot boundaries of the data.
#
#
# ####2️⃣ Regression Task
# Load ```regression_dataset.csv``` using pandas.
# - Split the data: Feature: Feature; Target: Target
# - Apply Linear Regression and Make predictions.\
# - Plot regression line on the scatter plot, along with the data
#
#
# ####📁 Provided Files:
# - [classification_dataset.csv](https://drive.google.com/file/d/1-mvUU90HuAWkSNanvdQFCGNb0WbkolsQ/view?usp=sharing)
# - [regression_dataset.csv](https://drive.google.com/file/d/1_ayHv1JRRV_3kPN-EgxGBANzPb8p3ejB/view?usp=sharing)
#
#
# **⏰ Time Limit:** 20 minutes

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.svm import SVC

import matplotlib.pyplot as plt

# %%
# --------- Classification Task ---------

# Load classification dataset


# Split data


# Apply KNN Classifier


# Decision Boundaries


# Plot

# %%
# --------- Regression Task ---------

# Load regression dataset


# Split data


# Apply Linear Regression


# Plot regression line
