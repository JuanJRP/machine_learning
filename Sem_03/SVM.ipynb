# %% [markdown]
# # **Support Vector Boundary**

# %% [markdown]
# Isotropic data generator documentation [aquí](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html#sklearn.datasets.make_blobs) \
# Support vector classifier documentation [aquí](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.datasets import make_blobs

# %%
# we create 40 separable points
X, y = make_blobs(n_samples = 100 , n_features= 2, centers = 2 , random_state = 6)

_, ax = plt.subplots(figsize=(5,4))
ax.scatter(X[:, 0], X[:, 1], c=y, s=30, edgecolors="k", cmap='Set1')

# %%
clf = SVC(kernel = "linear" )
clf.fit(X, y)
# Out:
# SVC(kernel='linear')

# %%
offset = 0.2
x_min, x_max = X[:, 0].min() - offset, X[:, 0].max() + offset
y_min, y_max = X[:, 1].min() - offset, X[:, 1].max() + offset

# Crear el grid de las fronteras de decision
X_grid, y_grid = np.meshgrid(np.linspace( x_min , x_max , 100), np.linspace( y_min , y_max , 100))

# Predecir los valores del grid
predictions = clf.decision_function( np.c_[X_grid.ravel(), y_grid.ravel()] )
print (predictions.shape)

# Encajar las predicciones al tamaño del grid
predictions = predictions.reshape( X_grid.shape )
print (predictions.shape)
# Out:
# (10000,)
# (100, 100)

# %%
_, ax = plt.subplots (figsize=(8,5))
ax.scatter(X[:, 0], X[:, 1], c=y, s=30, edgecolors="k", cmap='Set1')

# plot decision boundary and margins
ax.contour( X_grid , y_grid , predictions , colors='k', levels=[-1, 0, 1], alpha=0.5, linestyles=['--', '-', '--'])

# plot support vectors
ax.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s=100,
           linewidth=1, facecolors='none', edgecolors='k')

ax.set_xlim(X_grid.min()-.1, X_grid.max()+.1)
ax.set_ylim(y_grid.min()-.1, y_grid.max()+.1)

ax.set_xticks(())
ax.set_yticks(())
# Out:
# []

# %%
pred_grid = clf.predict(np.c_[X_grid.ravel(), y_grid.ravel()])
pred_grid = pred_grid.reshape(X_grid.shape)

# %%
_, ax = plt.subplots (figsize=(5,4))
ax.pcolormesh( X_grid , y_grid , pred_grid , cmap = "Set1")
ax.scatter ( X[:,0] , X[:,1] , c = y , edgecolors = 'k', cmap = "Set1")
plt.tight_layout()
ax.set_xticks(())
ax.set_yticks(())
# Out:
# []

# %% [markdown]
# ## In real data

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets import load_iris

# %%
# import some data to play with
iris = _
X = _   # Pick 2 features
Y = _

# %%
# Create an instance of SVM and fit the data.
clf = _
clf.fit( _ , _ )

# %%
# Plot decision boundaries
_
