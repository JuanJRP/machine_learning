# %% [markdown]
# ##Let's start on the basics. Variables and arrays
# First, import some libraries

# %%
import numpy as np

# %%
array_1 = np.array([0, 1, 2, 3])
array_2 = np.random.randint(0,10,len(array_1))

print(array_1, array_2)
print(type(array_1), type(array_2))
print(array_1.shape, array_2.shape)
# Out:
# [0 1 2 3] [5 2 1 0]
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# (4,) (4,)

# %%
array_s = array_1 + array_2
print(array_s)
# Out:
# [5 3 3 3]

# %%
array_1[2] = 70
print(array_1)
# Out:
# [ 0  1 70  3]

# %%
print(array_1 + array_2)
# Out:
# [ 3  1 70  7]

# %%
array_m = array_1 * array_2
print(array_m)
# Out:
# [ 0  0  0 12]

# %%
array_d = np.dot(array_1 , array_2)
print(array_d)
# Out:
# 12

# %% [markdown]
# ##Images

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/content/drive/MyDrive/Machine_Learning/machine_learning/Images/lena.jpg")
plt.imshow(img)

# %%
img.size
# Out:
# 360000

# %%
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img2)
print(type(img2),img.shape)
# Out:
# <class 'numpy.ndarray'> (300, 400, 3)

# %%
# !git clone https://github.com/JuanJRP/machine_learning.git
# Out:
# Cloning into 'machine_learning'...
# remote: Enumerating objects: 172, done.
# remote: Counting objects: 100% (71/71), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 172 (delta 50), reused 22 (delta 22), pack-reused 101 (from 1)
# Receiving objects: 100% (172/172), 173.10 KiB | 4.12 MiB/s, done.
# Resolving deltas: 100% (74/74), done.

# %%
print(img2[0:10, 0:10, 1])
# Out:
# [[ 6 10  0  7  2  0  0  7  5  6]
#  [ 8 49 48 69 64 57 57 54 60 60]
#  [ 0 54 56 63 55 57 60 55 57 53]
#  [ 6 68 63 63 55 58 64 64 63 60]
#  [ 2 58 55 66 66 59 56 61 50 51]
#  [ 0 58 53 66 70 58 52 63 53 55]
#  [ 0 57 45 51 55 45 43 61 58 60]
#  [ 1 68 60 63 68 62 59 73 59 60]
#  [ 4 59 56 62 54 54 58 56 60 58]
#  [ 4 59 56 62 54 54 58 56 56 54]]

# %%
#Opcion 1
img2[0:50, 0:50, 0] = 255
img2[0:50, 0:50, 1] = 255
img2[0:50, 0:50, 2] = 255

#Opcion 2
img2[0:50, 0:50, 0:3] = 255

plt.imshow(img2)

# %%
lena_face = img2[100:200, 170:270, 0:3]
plt.imshow(lena_face)

# %%
img2[100:200, 20:120, 0:3] = lena_face
plt.imshow(img2)
