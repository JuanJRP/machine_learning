# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples = _ , n_features = _ , n_redundant = 0, n_informative = 2, n_clusters_per_class = 1, n_classes = _, random_state = _)

_, ax = plt.subplots(figsize=( _ , _ ))
ax.scatter( _ , _ , c = _ , cmap = 'Paired')
